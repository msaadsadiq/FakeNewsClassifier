# %% [markdown]
# # Getting started with Word2Vec in Gensim and making it work!
#
# The idea behind Word2Vec is pretty simple. We are making and assumption that you can tell the meaning of a word by the company it keeps. This is analogous to the saying *show me your friends, and I'll tell who you are*. So if you have two words that have very similar neighbors (i.e. the usage context is about the same), then these words are probably quite similar in meaning or are at least highly related. For example, the words `shocked`,`appalled` and `astonished` are typically used in a similar context.
#
# In this tutorial, you will learn how to use the Gensim implementation of Word2Vec and actually get it to work! I have heard a lot of complaints about poor performance etc, but its really a combination of two things, (1) your input data and (2) your parameter settings. Note that the training algorithms in this package were ported from the [original Word2Vec implementation by Google](https://arxiv.org/pdf/1301.3781.pdf) and extended with additional functionality.

# %% [markdown]
# ### Imports and logging
#
# First, we start with our imports and get logging established:

# %%
# imports needed and set up logging
import gzip
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import pandas
from scipy import spatial

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary=True)
# Out:
# 2018-10-26 17:40:05,742 : INFO : loading projection weights from ./GoogleNews-vectors-negative300.bin
# 2018-10-26 17:40:57,022 : INFO : loaded (3000000, 300) matrix from ./GoogleNews-vectors-negative300.bin

# %% [markdown]
# ### Dataset
# Next, is our dataset. The secret to getting Word2Vec really working for you is to have lots and lots of text data. In this case I am going to use data from the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset. This dataset has full user reviews of cars and hotels. I have specifically concatenated all of the hotel reviews into one big file which is about 97MB compressed and 229MB uncompressed. We will use the compressed file for this tutorial. Each line in this file represents a hotel review. You can download the OpinRank Word2Vec dataset here.
#
# To avoid confusion, while gensim’s word2vec tutorial says that you need to pass it a sequence of sentences as its input, you can always pass it a whole review as a sentence (i.e. a much larger size of text), and it should not make much of a difference.
#
# Now, let's take a closer look at this data below by printing the first line. You can see that this is a pretty hefty review.

# %%
data_file="reviews_data.txt.gz"

with gzip.open ('reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %% [markdown]
# ### Read files into a list
# Now that we've had a sneak peak of our dataset, we can read it into a list so that we can pass this on to the Word2Vec model. Notice in the code below, that I am directly reading the
# compressed file. I'm also doing a mild pre-processing of the reviews using `gensim.utils.simple_preprocess (line)`. This does some basic pre-processing such as tokenization, lowercasing, etc and returns back a list of tokens (words). Documentation of this pre-processing method can be found on the official [Gensim documentation site](https://radimrehurek.com/gensim/utils.html).

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10000==0):
                logging.info ("read {0} reviews".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess (line)

# read the tokenized reviews into a list
# each review item becomes a serries of words
# so this becomes a list of lists
documents = list (read_input (data_file))
logging.info ("Done reading data file")
# Out:
# 2018-10-26 15:51:41,163 : INFO : reading file reviews_data.txt.gz...this may take a while
# 2018-10-26 15:51:41,166 : INFO : read 0 reviews
# 2018-10-26 15:51:43,243 : INFO : read 10000 reviews
# 2018-10-26 15:51:45,116 : INFO : read 20000 reviews
# 2018-10-26 15:51:47,250 : INFO : read 30000 reviews
# 2018-10-26 15:51:49,262 : INFO : read 40000 reviews
# 2018-10-26 15:51:51,373 : INFO : read 50000 reviews
# 2018-10-26 15:51:53,436 : INFO : read 60000 reviews
# 2018-10-26 15:51:55,167 : INFO : read 70000 reviews
# 2018-10-26 15:51:57,148 : INFO : read 80000 reviews
# 2018-10-26 15:51:58,802 : INFO : read 90000 reviews
# 2018-10-26 15:52:00,421 : INFO : read 100000 reviews
# 2018-10-26 15:52:02,049 : INFO : read 110000 reviews
# 2018-10-26 15:52:03,738 : INFO : read 120000 reviews
# 2018-10-26 15:52:05,437 : INFO : read 130000 reviews
# 2018-10-26 15:52:07,216 : INFO : read 140000 reviews
# 2018-10-26 15:52:08,883 : INFO : read 150000 reviews
# 2018-10-26 15:52:10,540 : INFO : read 160000 reviews
# 2018-10-26 15:52:12,897 : INFO : read 170000 reviews
# 2018-10-26 15:52:14,607 : INFO : read 180000 reviews
# 2018-10-26 15:52:16,274 : INFO : read 190000 reviews
# 2018-10-26 15:52:18,101 : INFO : read 200000 reviews
# 2018-10-26 15:52:19,838 : INFO : read 210000 reviews
# 2018-10-26 15:52:21,606 : INFO : read 220000 reviews
# 2018-10-26 15:52:23,211 : INFO : read 230000 reviews
# 2018-10-26 15:52:24,885 : INFO : read 240000 reviews
# 2018-10-26 15:52:26,565 : INFO : read 250000 reviews
# 2018-10-26 15:52:27,439 : INFO : Done reading data file

# %% [markdown]
# ## Training the Word2Vec model
#
# Training the model is fairly straightforward. You just instantiate Word2Vec and pass the reviews that we read in the previous step (the `documents`). So, we are essentially passing on a list of lists. Where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary. And by vocabulary, I mean a set of unique words.
#
# After building the vocabulary, we just need to call `train(...)` to start training the Word2Vec model. Training on the [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset takes about 10 minutes so please be patient while running your code on this dataset.
#
# Behind the scenes we are actually training a simple neural network with a single hidden layer. But, we are actually not going to use the neural network after training. Instead, the goal is to learn the weights of the hidden layer. These weights are essentially the word vectors that we’re trying to learn.

# %%
model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=40)
model.train(documents,total_examples=len(documents),epochs=10)
# Out:
# 2018-10-26 15:53:01,690 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2018-10-26 15:53:01,692 : INFO : collecting all words and their counts
# 2018-10-26 15:53:01,693 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-10-26 15:53:01,966 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2018-10-26 15:53:02,216 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2018-10-26 15:53:02,532 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2018-10-26 15:53:02,843 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2018-10-26 15:53:03,197 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2018-10-26 15:53:03,585 : INFO : PROGRESS: at sentence #60000, processed 11013723 words, keeping 76781 word types
# 2018-10-26 15:53:03,857 : INFO : PROGRESS: at sentence #70000, processed 12637525 words, keeping 83194 word types
# 2018-10-26 15:53:04,113 : INFO : PROGRESS: at sentence #80000, processed 14099751 words, keeping 88454 word types
# 2018-10-26 15:53:04,387 : INFO : PROGRESS: at sentence #90000, processed 15662149 words, keeping 93352 word types
# 2018-10-26 15:53:04,641 : INFO : PROGRESS: at sentence #100000, processed 17164487 words, keeping 97881 word types
# 2018-10-26 15:53:04,883 : INFO : PROGRESS: at sentence #110000, processed 18652292 words, keeping 102127 word types
# 2018-10-26 15:53:05,138 : INFO : PROGRESS: at sentence #120000, processed 20152529 words, keeping 105918 word types
# 2018-10-26 15:53:05,394 : INFO : PROGRESS: at sentence #130000, processed 21684330 words, keeping 110099 word types
# 2018-10-26 15:53:05,654 : INFO : PROGRESS: at sentence #140000, processed 23330206 words, keeping 114103 word types
# 2018-10-26 15:53:05,896 : INFO : PROGRESS: at sentence #150000, processed 24838754 words, keeping 118169 word types
# 2018-10-26 15:53:06,151 : INFO : PROGRESS: at sentence #160000, processed 26390910 words, keeping 118665 word types
# 2018-10-26 15:53:06,396 : INFO : PROGRESS: at sentence #170000, processed 27913916 words, keeping 123350 word types
# 2018-10-26 15:53:06,656 : INFO : PROGRESS: at sentence #180000, processed 29535612 words, keeping 126742 word types
words/s, in_qsize 79, out_qsize 0
# 2018-10-26 15:59:02,231 : INFO : EPOCH 10 - PROGRESS: at 88.08% examples, 1272949 words/s, in_qsize 79, out_qsize 0
# 2018-10-26 15:59:03,233 : INFO : EPOCH 10 - PROGRESS: at 92.73% examples, 1275344 words/s, in_qsize 78, out_qsize 2
# 2018-10-26 15:59:04,243 : INFO : EPOCH 10 - PROGRESS: at 96.93% examples, 1273035 words/s, in_qsize 80, out_qsize 0
# 2018-10-26 15:59:04,693 : INFO : worker thread finished; awaiting finish of 39 more threads
# 2018-10-26 15:59:04,703 : INFO : worker thread finished; awaiting finish of 38 more threads
# 2018-10-26 15:59:04,718 : INFO : worker thread finished; awaiting finish of 37 more threads
# 2018-10-26 15:59:04,725 : INFO : worker thread finished; awaiting finish of 36 more threads
# 2018-10-26 15:59:04,737 : INFO : worker thread finished; awaiting finish of 35 more threads
# 2018-10-26 15:59:04,744 : INFO : worker thread finished; awaiting finish of 34 more threads
# 2018-10-26 15:59:04,746 : INFO : worker thread finished; awaiting finish of 33 more threads
# 2018-10-26 15:59:04,754 : INFO : worker thread finished; awaiting finish of 32 more threads
# 2018-10-26 15:59:04,755 : INFO : worker thread finished; awaiting finish of 31 more threads
# 2018-10-26 15:59:04,761 : INFO : worker thread finished; awaiting finish of 30 more threads
# 2018-10-26 15:59:04,763 : INFO : worker thread finished; awaiting finish of 29 more threads
# 2018-10-26 15:59:04,770 : INFO : worker thread finished; awaiting finish of 28 more threads
# 2018-10-26 15:59:04,779 : INFO : worker thread finished; awaiting finish of 27 more threads
# 2018-10-26 15:59:04,781 : INFO : worker thread finished; awaiting finish of 26 more threads
# 2018-10-26 15:59:04,783 : INFO : worker thread finished; awaiting finish of 25 more threads
# 2018-10-26 15:59:04,786 : INFO : worker thread finished; awaiting finish of 24 more threads
# 2018-10-26 15:59:04,791 : INFO : worker thread finished; awaiting finish of 23 more threads
# 2018-10-26 15:59:04,798 : INFO : worker thread finished; awaiting finish of 22 more threads
# 2018-10-26 15:59:04,806 : INFO : worker thread finished; awaiting finish of 21 more threads
# 2018-10-26 15:59:04,814 : INFO : worker thread finished; awaiting finish of 20 more threads
# 2018-10-26 15:59:04,816 : INFO : worker thread finished; awaiting finish of 19 more threads
# 2018-10-26 15:59:04,818 : INFO : worker thread finished; awaiting finish of 18 more threads
# 2018-10-26 15:59:04,820 : INFO : worker thread finished; awaiting finish of 17 more threads
# 2018-10-26 15:59:04,820 : INFO : worker thread finished; awaiting finish of 16 more threads
# 2018-10-26 15:59:04,822 : INFO : worker thread finished; awaiting finish of 15 more threads
# 2018-10-26 15:59:04,827 : INFO : worker thread finished; awaiting finish of 14 more threads
# 2018-10-26 15:59:04,828 : INFO : worker thread finished; awaiting finish of 13 more threads
# 2018-10-26 15:59:04,828 : INFO : worker thread finished; awaiting finish of 12 more threads
# 2018-10-26 15:59:04,829 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2018-10-26 15:59:04,830 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2018-10-26 15:59:04,831 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2018-10-26 15:59:04,836 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2018-10-26 15:59:04,841 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2018-10-26 15:59:04,844 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2018-10-26 15:59:04,845 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2018-10-26 15:59:04,847 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2018-10-26 15:59:04,851 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-10-26 15:59:04,852 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-10-26 15:59:04,853 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-10-26 15:59:04,856 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-10-26 15:59:04,857 : INFO : EPOCH - 10 : training on 41519355 raw words (30350806 effective words) took 23.8s, 1277305 effective words/s
# 2018-10-26 15:59:04,858 : INFO : training on a 415193550 raw words (303492568 effective words) took 236.8s, 1281788 effective words/s
# (303492568, 415193550)

# %% [markdown]
# ## Now, let's look at some output
# This first example shows a simple case of looking up words similar to the word `dirty`. All we need to do here is to call the `most_similar` function and provide the word `dirty` as the positive example. This returns the top 10 similar words.

# %%
def avg_feature_vector(words, model, num_features):
    #function to average all words vectors in a given paragraph
    featureVec = np.zeros((num_features,), dtype="float32")
    nwords = 0

    for word in words:
        nwords = nwords+1
        featureVec = np.add(featureVec, model.wv.get_vector(word))

    if nwords>0:
        featureVec = np.divide(featureVec, nwords)
    return featureVec

# %%
sentence_2 = "Hundreds Palestinians flee floods in Gaza as Israel opens dams"
sentence_2_avg_vector = avg_feature_vector(sentence_2.split(), model=model, num_features=300)
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
sentence_1 = "Hundreds Palestinians were evacuated from their homes Sunday morning after Israeli authorities opened number dams near the flooding the Gaza Valley in the wake recent severe winter"
sentence_1_avg_vector = avg_feature_vector(sentence_1.split(), model=model, num_features=300)
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
sentence_1_avg_vector = avg_feature_vector(words, model=model, num_features=300)
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
embded = avg_feature_vector(list(filter(lambda x: x in model.vocab, df.Body[0].split())), model=model, num_features=300)
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
embded.reshape(1,-1)
# Out:
# array([[ 0.04116887,  0.05220095,  0.03116181,  0.03356571, -0.0278487 ,
#         -0.03325611, -0.00654184, -0.08596455,  0.08265134,  0.07709363,
#         -0.02667697, -0.10175342, -0.01959968,  0.04229806, -0.06995567,
#         -0.00867642, -0.000292  ,  0.06517272, -0.02176409, -0.01755957,
#         -0.01371862,  0.03844424, -0.02036962, -0.01049426,  0.03681479,
#         -0.03064112, -0.06727696,  0.02893789,  0.03638294, -0.03837384,
#          0.008601  , -0.03856645, -0.05807032, -0.0066028 , -0.00654647,
#         -0.0353211 , -0.00530177, -0.03146559, -0.00054639,  0.05194515,
#          0.03757776, -0.00895299,  0.06523016, -0.02891982,  0.00709442,
#         -0.05471928, -0.06348508,  0.0402124 , -0.02746599,  0.03954405,
#          0.06720875,  0.01042708, -0.02429103, -0.01328754, -0.04901773,
#          0.02334564, -0.07133711, -0.00444152,  0.01180557, -0.05457889,
#         -0.0662168 ,  0.06294639, -0.03937907, -0.10272601, -0.02113726,
#         -0.00306502,  0.00174435,  0.07157054, -0.03891621,  0.03186421,
#         -0.01789439, -0.01295831,  0.10110202,  0.02273805, -0.09558259,
#         -0.06486546,  0.06029955,  0.05398883,  0.01048338,  0.05303894,
#          0.03053281, -0.05626795, -0.00997617, -0.00308828, -0.02907118,
#         -0.0380182 , -0.08768055,  0.06079684, -0.02278381,  0.00122571,
#          0.04228619,  0.02076233, -0.05111442, -0.07968018, -0.0412971 ,
#         -0.03609518,  0.01746747,  0.01388861,  0.01236877,  0.0141251 ,
#          0.02894119, -0.04949028,  0.00356871,  0.02204514,  0.00505791,
#         -0.06726933, -0.01066655, -0.04516356,  0.00686796, -0.0523553 ,
#         -0.02541274,  0.01598955, -0.013695  , -0.02147408,  0.01983912,
#         -0.00136745,  0.08857668,  0.03500336,  0.07325455,  0.08128502,
#         -0.10767677,  0.03249699, -0.08980364,  0.0268946 , -0.03984537,
#         -0.01981147, -0.02506151, -0.05701274,  0.01111406,  0.04270621,
#          0.02945503, -0.06113425, -0.06801163, -0.04482245, -0.04795728,
#         -0.06923833,  0.03319152, -0.08027618, -0.01803765,  0.03335923,
#          0.00050664, -0.05816318,  0.07860444,  0.01823893,  0.02469843,
#         -0.00066661, -0.0141558 , -0.04071947, -0.11211494,  0.00363433,
#          0.08688525, -0.01792396, -0.04974985,  0.0410446 , -0.01723031,
#         -0.04380668, -0.01015575, -0.07606839, -0.00738346, -0.01362844,
#         -0.0192506 ,  0.04604076,  0.01229838,  0.01339396,  0.00124083,
#         -0.02352208,  0.05111508, -0.00114636,  0.05065782, -0.03922398,
#         -0.12657163, -0.00067059, -0.06493111, -0.06661531,  0.00867827,
#         -0.06065542,  0.05915089, -0.0359957 , -0.07088368,  0.00294023,
#         -0.08513206, -0.05255125, -0.02566299, -0.01247463,  0.0024246 ,
#         -0.03014363, -0.00767283,  0.04108674,  0.09380458,  0.09819258,
#         -0.00377418, -0.00189129,  0.0404181 , -0.00301604, -0.10144684,
#          0.0403882 , -0.0317733 , -0.00814095, -0.02570142, -0.10442865,
#          0.06542285,  0.04731895, -0.00610338, -0.01886712,  0.01118063,
#         -0.01957183,  0.00326625, -0.01461847,  0.03075109, -0.0036796 ,
#         -0.03846044, -0.0128655 , -0.00601905,  0.07302812, -0.05882917,
#         -0.00156157,  0.03058136,  0.01776025, -0.10401814,  0.02640945,
#          0.02528426,  0.00477261, -0.00253128, -0.01919659,  0.05570504,
#         -0.06412092,  0.01970942,  0.07622542,  0.06393199, -0.00787817,
#          0.04605594, -0.0093934 ,  0.01742402,  0.03570461, -0.01582278,
#         -0.05194817,  0.02825773, -0.06198092,  0.07841185, -0.0089226 ,
#          0.00826678,  0.00275077,  0.00159984, -0.08936486,  0.01981361,
#          0.01917541,  0.05513224,  0.02074476, -0.01431538, -0.01691468,
#          0.0139347 , -0.00713962,  0.01056044,  0.05152926,  0.0658436 ,
#         -0.04625171,  0.07890449, -0.00539825, -0.0456099 , -0.00058271,
#         -0.01739027,  0.00414037,  0.00572143,  0.0883633 ,  0.08381064,
#          0.11897662, -0.04059187,  0.00125057,  0.00268669, -0.01080396,
#          0.03709957,  0.06879622,  0.02734623,  0.00126447,  0.04858155,
#         -0.05061485, -0.04914414, -0.07396702,  0.00235194, -0.06237856,
#         -0.01535315,  0.0012743 ,  0.03969946,  0.08997483,  0.05468154,
#         -0.00742946, -0.07257386,  0.04265665,  0.03153056,  0.05201941,
#         -0.09870005, -0.00953461, -0.09327625,  0.01182535, -0.01010701,
#          0.03472176, -0.04428896, -0.02908909,  0.05269815, -0.02654241]],
#       dtype=float32)

# %%
embeddings =pandas.DataFrame((avg_feature_vector(list(filter(lambda x: x in model.vocab, df.Body[0].split())), model=model, num_features=300)).reshape(1,-1))
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
for sents in df.Body:
    filtered_list = list(filter(lambda x: x in model.vocab, sents.split()))
    avg_embed = avg_feature_vector(filtered_list, model=model, num_features=300)
    avg_embed_trans = avg_embed.reshape(1,-1)
    temp_df = pandas.DataFrame(avg_embed_trans)
    embeddings = embeddings.append(temp_df)
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
samp1filt = list(filter(lambda x: x in model.vocab, df.Headline[0].split()))
samp1avg = avg_feature_vector(filtered_list, model=model, num_features=300)
samp2filt = list(filter(lambda x: x in model.vocab, df.Body[0].split()))
samp2avg = avg_feature_vector(filtered_list, model=model, num_features=300)
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
1 - spatial.distance.cosine(samp1avg, samp2avg)
# Out:
# 1.0

# %%
df
# Out:
#                                                Headline  \
# 0     Hundreds Palestinians flee floods in Gazas Isr...
# 1     Spider burrowed through tourists stomach and u...
# 2     NasConfirms Earth Will Experience 6 Days Total...
# 3     Banksy Arrested & Real Identity Revealed Is Th...
# 4     Woman detained in Lebanon is not al-Baghdadis ...
# 5     No Robert Plant Didnât Rip Up an $800 Million ...
# 6     NET Extra: Back-from-the-dead Catholic priest ...
# 7     Rumor debunked: RoboCop-style robots are not p...
# 8     Fisherman lands 19 STONE catfish which could b...
# 9     Student accidentally sets college on fire duri...
# 10    Pope Francis turns out not to have made pets i...
# 11    Macaulay Culkin Hasnât Died Despite What Every...
# 12    No its not Tiger Woods selling an island in La...
# 13     Indian civil servant sacked after 24-year sickie
# 14    Soldier Gunman Killed In Shooting Incident Nea...
# 15    Mystery woman behind the richest hands on the ...
# 16    New Audio Reveals Pause in Gunfire When Michae...
# 17    11 Tripoli Planes Still Missing Sparks 9/11 Co...
# 18    IndiRape Crisis Sees Mob Castrate Alleged Sex ...
# 19              Met police denies reports Banksy arrest
# 20    Video: Marine saved by helmet after Taliban sn...
# 21      Vogueâs Rat Infestation: Disturbing New Details
# 22    ADVISORY-Islamist rebel leader killed in U.S. ...
# 23    Video: Marine survives Taliban sniper headshot...
# 24    Weather Reporter Caught Writing His Name In Th...
# 25    Lego letter to parents in 1974 on gender equal...
# 26    After Giving Homeless Man $100 This Guy Secret...
# 27    British hostage David Haines beheaded by Islam...
# 28    Woman Ting Su Finds Husband Cheating With Her ...
# 29    Jeh Johnson: Politicians Shouldnt Feed The Fla...
# ...                                                 ...
# 7088  Climate change: the Hoax that Costs Us $4 Bill...
# 7089  Climate change: the Hoax that Costs Us $4 Bill...
# 7090  Climate change: the Hoax that Costs Us $4 Bill...
# 7091  Climate change: the Hoax that Costs Us $4 Bill...
# 7092  Climate change: the Hoax that Costs Us $4 Bill...
# 7093          Sign That Obamacare Exchanges Are Failing
# 7094          Sign That Obamacare Exchanges Are Failing
# 7095          Sign That Obamacare Exchanges Are Failing
# 7096          Sign That Obamacare Exchanges Are Failing
# 7097          Sign That Obamacare Exchanges Are Failing
# 7098  Republicans call Obamacare failure. These 7 ch...
# 7099  Republicans call Obamacare failure. These 7 ch...
# 7100  Republicans call Obamacare failure. These 7 ch...
# 7101  Republicans call Obamacare failure. These 7 ch...
# 7102  Republicans call Obamacare failure. These 7 ch...
# 7103  CBOâs Alternate Facts Show Obamacare is Unsust...
# 7104  CBOâs Alternate Facts Show Obamacare is Unsust...
# 7105  CBOâs Alternate Facts Show Obamacare is Unsust...
# 7106  CBOâs Alternate Facts Show Obamacare is Unsust...
# 7107  CBOâs Alternate Facts Show Obamacare is Unsust...
# 7108                               Why Obamacare failed
# 7109                               Why Obamacare failed
# 7110                               Why Obamacare failed
# 7111                               Why Obamacare failed
# 7112                               Why Obamacare failed
# 7113  The success the Affordable Care Act is hugely ...
# 7114  The success the Affordable Care Act is hugely ...
# 7115  The success the Affordable Care Act is hugely ...
# 7116  The success the Affordable Care Act is hugely ...
# 7117  The success the Affordable Care Act is hugely ...
#
#                                                    Body    Stance
# 0     Hundreds Palestinians were evacuated from thei...     agree
# 1     Fear not arachnophobes the story Bunburys spid...  disagree
# 2     Thousands people have been duped by fake news ...     agree
# 3     If youâve seen story floating around on your F...     agree
# 4     An Iraqi official denied that woman detained i...     agree
# 5     Led Zeppelin fans will be disappointed to lear...     agree
# 6     71 years old cleric Father John Micheal Oâneal...     agree
# 7     Knightscope co-founder Stacy Stephens said rum...     agree
# 8     Dino Ferrari hooked the whopper wels catfish w...     agree
# 9     He popped the question â€” and burned down his...     agree
# 10    NEW YORK â€” Pope Francis has given hope to ga...  disagree
# 11    Claim: Actor Macaulay Culkin has died.\n\nFALS...     agree
# 12    luxury island previously owned by Tiger Woods ...  disagree
# 13    An Indian public official has been sacked for ...     agree
# 14    gunman opened fire at Canadas National War Mem...     agree
# 15    The identity the couple behind the mega-succes...     agree
# 16    Video messaging app Glide on Thursday said it ...     agree
# 17    Eleven planes missing from Tripoli Airport aft...     agree
# 18    An alleged attempted rapist in Indireceived gr...     agree
# 19    Letâs clear this one up quickly.\n\nUS website...     agree
# 20    The marine was shot during mission in the dang...     agree
# 21    The rodents have pestered the staffs Vanity Fa...     agree
# 22    MOGADISHU Sept 5 (Reuters) - The alert and sto...  disagree
# 23    video US marine surviving being shot in the he...     agree
# 24    Brian Williams took moment on Mondayâs â€œNBC ...  disagree
# 25    picture letter to parents from box Lego in the...     agree
# 26    Awwwww!\nThis is such heartwarming story!\nWhe...     agree
# 27    propagandvideo released by ISIS has set off ra...     agree
# 28    What do you do when your twin is having sex wi...     agree
# 29    Homeland Security Secretary Jeh Johnson says I...     agree
# ...                                                 ...       ...
# 7088  In January group Cornell University undergradu...  disagree
# 7089  The basic science behind climate change is act...  disagree
# 7090  With Hurricane Matthew wreaking havoc the Left...     agree
# 7091  One the main lines evidence used by the Obamad...     agree
# 7092  Climate change is the biggest scam in the hist...     agree
# 7093  Yet more bad news for Obamacare this week: Mol...     agree
# 7094  Congressional Republicans evidently hoping tha...  disagree
# 7095  Millions may lose coverage next year if Congre...     agree
# 7096  Come November the grim trudge across the incre...     agree
# 7097  Remember how much Republicans wanted to repeal...  disagree
# 7098  Yet more bad news for Obamacare this week: Mol...  disagree
# 7099  Congressional Republicans evidently hoping tha...     agree
# 7100  Millions may lose coverage next year if Congre...  disagree
# 7101  Come November the grim trudge across the incre...  disagree
# 7102  Remember how much Republicans wanted to repeal...     agree
# 7103  Yet more bad news for Obamacare this week: Mol...     agree
# 7104  Congressional Republicans evidently hoping tha...  disagree
# 7105  Millions may lose coverage next year if Congre...     agree
# 7106  Come November the grim trudge across the incre...     agree
# 7107  Remember how much Republicans wanted to repeal...  disagree
# 7108  Yet more bad news for Obamacare this week: Mol...     agree
# 7109  Congressional Republicans evidently hoping tha...  disagree
# 7110  Millions may lose coverage next year if Congre...     agree
# 7111  Come November the grim trudge across the incre...     agree
# 7112  Remember how much Republicans wanted to repeal...  disagree
# 7113  Yet more bad news for Obamacare this week: Mol...  disagree
# 7114  Congressional Republicans evidently hoping tha...     agree
# 7115  Millions may lose coverage next year if Congre...  disagree
# 7116  Come November the grim trudge across the incre...  disagree
# 7117  Remember how much Republicans wanted to repeal...     agree
#
# [7118 rows x 3 columns]

# %%
embeddings = embeddings.drop(columns=['Class','f'])

# %%
embeddings.to_csv("embeddings.csv", sep=',')

# %%
reshaped = sentence_1_avg_vector.reshape(1,-1)

# %%
np.shape(sentence_2_avg_vector.reshape(1,-1))
# Out:
# (1, 300)

# %%
df = pandas.DataFrame(sentence_1_avg_vector.reshape(1,-1))

# %%
df2 = pandas.DataFrame(sentence_2_avg_vector.reshape(1,-1))

# %%
from numpy import genfromtxt

# %%
df = pandas.read_csv("df = pandas.read_csv("Binary.csv", sep=',', error_bad_lines=False)df = pandas.read_csv("Binary.csv", sep=',', error_bad_lines=False)df = pandas.read_csv("Binary.csv", sep=',', error_bad_lines=False)zzzzzzzzzzzzzzzzzzzzzzzzz.csv", sep=',', error_bad_lines=False)vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv

# %%
filtered_list = list(filter(lambda x: x in model.vocab, df.Headline[0].split()))

# %%
1 - spatial.distance.cosine(sentence_1_avg_vector, sentence_2_avg_vector)
# Out:
#                                                Headline  \
# 0     Hundreds Palestinians flee floods in Gazas Isr...
# 1     Spider burrowed through tourists stomach and u...
# 2     NasConfirms Earth Will Experience 6 Days Total...
# 3     Banksy Arrested & Real Identity Revealed Is Th...
# 4     Woman detained in Lebanon is not al-Baghdadis ...
# 5     No Robert Plant Didnât Rip Up an $800 Million ...
# 6     NET Extra: Back-from-the-dead Catholic priest ...
# 7     Rumor debunked: RoboCop-style robots are not p...
# 8     Fisherman lands 19 STONE catfish which could b...
# 9     Student accidentally sets college on fire duri...
# 10    Pope Francis turns out not to have made pets i...
# 11    Macaulay Culkin Hasnât Died Despite What Every...
# 12    No its not Tiger Woods selling an island in La...
# 13     Indian civil servant sacked after 24-year sickie
# 14    Soldier Gunman Killed In Shooting Incident Nea...
# 15    Mystery woman behind the richest hands on the ...
# 16    New Audio Reveals Pause in Gunfire When Michae...
# 17    11 Tripoli Planes Still Missing Sparks 9/11 Co...
# 18    IndiRape Crisis Sees Mob Castrate Alleged Sex ...
# 19              Met police denies reports Banksy arrest
# 20    Video: Marine saved by helmet after Taliban sn...
# 21      Vogueâs Rat Infestation: Disturbing New Details
# 22    ADVISORY-Islamist rebel leader killed in U.S. ...
# 23    Video: Marine survives Taliban sniper headshot...
# 24    Weather Reporter Caught Writing His Name In Th...
# 25    Lego letter to parents in 1974 on gender equal...
# 26    After Giving Homeless Man $100 This Guy Secret...
# 27    British hostage David Haines beheaded by Islam...
# 28    Woman Ting Su Finds Husband Cheating With Her ...
# 29    Jeh Johnson: Politicians Shouldnt Feed The Fla...
# ...                                                 ...
# 7088  Climate change: the Hoax that Costs Us $4 Bill...
# 7089  Climate change: the Hoax that Costs Us $4 Bill...
# 7090  Climate change: the Hoax that Costs Us $4 Bill...
# 7091  Climate change: the Hoax that Costs Us $4 Bill...
# 7092  Climate change: the Hoax that Costs Us $4 Bill...
# 7093          Sign That Obamacare Exchanges Are Failing
# 7094          Sign That Obamacare Exchanges Are Failing
# 7095          Sign That Obamacare Exchanges Are Failing
# 7096          Sign That Obamacare Exchanges Are Failing
# 7097          Sign That Obamacare Exchanges Are Failing
# 7098  Republicans call Obamacare failure. These 7 ch...
# 7099  Republicans call Obamacare failure. These 7 ch...
# 7100  Republicans call Obamacare failure. These 7 ch...
# 7101  Republicans call Obamacare failure. These 7 ch...
# 7102  Republicans call Obamacare failure. These 7 ch...
# 7103  CBOâs Alternate Facts Show Obamacare is Unsust...
# 
# 7101  Come November the grim trudge across the incre...  disagree
# 7102  Remember how much Republicans wanted to repeal...     agree
# 7103  Yet more bad news for Obamacare this week: Mol...     agree
# 7104  Congressional Republicans evidently hoping tha...  disagree
# 7105  Millions may lose coverage next year if Congre...     agree
# 7106  Come November the grim trudge across the incre...     agree
# 7107  Remember how much Republicans wanted to repeal...  disagree
# 7108  Yet more bad news for Obamacare this week: Mol...     agree
# 7109  Congressional Republicans evidently hoping tha...  disagree
# 7110  Millions may lose coverage next year if Congre...     agree
# 7111  Come November the grim trudge across the incre...     agree
# 7112  Remember how much Republicans wanted to repeal...  disagree
# 7113  Yet more bad news for Obamacare this week: Mol...  disagree
# 7114  Congressional Republicans evidently hoping tha...     agree
# 7115  Millions may lose coverage next year if Congre...  disagree
# 7116  Come November the grim trudge across the incre...  disagree
# 7117  Remember how much Republicans wanted to repeal...     agree
#
# [7118 rows x 3 columns]

# %%
df = pandas.read_csv("relevancy.csv", sep=',', error_bad_lines=False)

# %%
df = pandas.read_csv("Binary.csv", sep=',', error_bad_lines=False)

# %%
df.append(df2)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.063072  0.035162  0.002528  0.002925 -0.018912 -0.097343 -0.042887
# 0  0.147607  0.079312 -0.071631  0.029242 -0.044415 -0.071875 -0.069897
#
#         7         8         9      ...          290       291       292  \
# 0 -0.038532  0.100540  0.082913    ...    -0.096976 -0.060467 -0.137662
# 0 -0.032141  0.086273  0.100830    ...    -0.162549 -0.061475 -0.245752
#
#         293       294       295       296       297       298       299
# 0 -0.026505  0.013073  0.006938 -0.126447 -0.009122  0.093155 -0.033905
# 0 -0.067810 -0.074834  0.059155 -0.161785 -0.054615  0.081311  0.004245
#
# [2 rows x 300 columns]

# %%
1 - spatial.distance.cosine(sentence_1_avg_vector, sentence_2_avg_vector)
# Out:
# 0.7869243025779724

# %%
w1= "polite"
vect = model.wv.get_vector(w1)
# Out:
# /home/saad/.conda/envs/textVAE2/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
import numpy as np

# %%
np.shape(vect)
# Out:
# (150,)

# %%
w1 = "shocked"
model.wv.most_similar (positive=w1)
# Out:
# [('horrified', 0.8127754926681519),
#  ('dismayed', 0.78623366355896),
#  ('amazed', 0.7840966582298279),
#  ('appalled', 0.7795482277870178),
#  ('stunned', 0.7516888976097107),
#  ('astonished', 0.7505988478660583),
#  ('surprised', 0.720969557762146),
#  ('suprised', 0.7207925319671631),
#  ('astounded', 0.7204748392105103),
#  ('surprized', 0.6929066777229309)]

# %% [markdown]
# That looks pretty good, right? Let's look at a few more. Let's look at similarity for `polite`, `france` and `shocked`.

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('courteous', 0.9174547791481018),
#  ('friendly', 0.8309274911880493),
#  ('cordial', 0.7990915179252625),
#  ('professional', 0.7945970892906189),
#  ('attentive', 0.7732747197151184),
#  ('gracious', 0.7469891309738159)]

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('canada', 0.6603403091430664),
#  ('germany', 0.6510637998580933),
#  ('spain', 0.6431018114089966),
#  ('barcelona', 0.61174076795578),
#  ('mexico', 0.6070996522903442),
#  ('rome', 0.6065913438796997)]

# %%
# look up top 6 words similar to 'shocked'
w1 = ["shocked"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('horrified', 0.80775386095047),
#  ('amazed', 0.7797470092773438),
#  ('astonished', 0.7748459577560425),
#  ('dismayed', 0.7680633068084717),
#  ('stunned', 0.7603034973144531),
#  ('appalled', 0.7466776371002197)]

# %% [markdown]
# That's, nice. You can even specify several positive examples to get things that are related in the provided context and provide negative examples to say what should not be considered as related. In the example below we are asking for all items that *relate to bed* only:

# %%
# get everything related to stuff on the bed
w1 = ["bed",'sheet','pillow']
w2 = ['couch']
model.wv.most_similar (positive=w1,negative=w2,topn=10)
# Out:
# [('duvet', 0.7086508274078369),
#  ('blanket', 0.7016597390174866),
#  ('mattress', 0.7002605199813843),
#  ('quilt', 0.6868821978569031),
#  ('matress', 0.6777950525283813),
#  ('pillowcase', 0.6413239240646362),
#  ('sheets', 0.6382123827934265),
#  ('foam', 0.6322235465049744),
#  ('pillows', 0.6320573687553406),
#  ('comforter', 0.5972476601600647)]

# %% [markdown]
# ### Similarity between two words in the vocabulary

# %% [markdown]
# You can even use the Word2Vec model to return the similarity between two words that are present in the vocabulary.

# %%
# similarity between two different words
model.wv.similarity(w1="dirty",w2="smelly")
# Out:
# 0.76181122646029453

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty",w2="dirty")
# Out:
# 1.0000000000000002

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty",w2="clean")
# Out:
# 0.25355593501920781

# %% [markdown]
# Under the hood, the above three snippets computes the cosine similarity between the two specified words using word vectors of each. From the scores, it makes sense that `dirty` is highly similar to `smelly` but `dirty` is dissimilar to `clean`. If you do a similarity between two identical words, the score will be 1.0 as the range of the cosine similarity score will always be between [0.0-1.0]. You can read more about cosine similarity scoring [here](https://en.wikipedia.org/wiki/Cosine_similarity).

# %% [markdown]
# ### Find the odd one out
# You can even use Word2Vec to find odd items given a list of items.

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["cat","dog","france"])
# Out:
# 'france'

# %%
# Which one is the odd one out in this list?
model.wv.doesnt_match(["bed","pillow","duvet","shower"])
# Out:
# 'shower'

# %% [markdown]
# ## Understanding some of the parameters
# To train the model earlier, we had to set some parameters. Now, let's try to understand what some of them mean. For reference, this is the command that we used to train the model.
#
# ```
# model = gensim.models.Word2Vec (documents, size=150, window=10, min_count=2, workers=10)
# ```
#
# ### `size`
# The size of the dense vector to represent each token or word. If you have very limited data, then size should be a much smaller value. If you have lots of data, its good to experiment with various sizes. A value of 100-150 has worked well for me.
#
# ### `window`
# The maximum distance between the target word and its neighboring word. If your neighbor's position is greater than the maximum window width to the left and the right, then, some neighbors are not considered as being related to the target word. In theory, a smaller window should give you terms that are more related. If you have lots of data, then the window size should not matter too much, as long as its a decent sized window.
#
# ### `min_count`
# Minimium frequency count of words. The model would ignore words that do not statisfy the `min_count`. Extremely infrequent words are usually unimportant, so its best to get rid of those. Unless your dataset is really tiny, this does not really affect the model.
#
# ### `workers`
# How many threads to use behind the scenes?

# %% [markdown]
# ## When should you use Word2Vec?
#
# There are many application scenarios for Word2Vec. Imagine if you need to build a sentiment lexicon. Training a Word2Vec model on large amounts of user reviews helps you achieve that. You have a lexicon for not just sentiment, but for most words in the vocabulary.
#
# Beyond, raw unstructured text data, you could also use Word2Vec for more structured data. For example, if you had tags for a million stackoverflow questions and answers, you could find tags that are related to a given tag and recommend the related ones for exploration. You can do this by treating each set of co-occuring tags as a "sentence" and train a Word2Vec model on this data. Granted, you still need a large number of examples to make it work.
